# %%
import wmi

# %%
import socket
hostname = socket.gethostname()
ip = socket.gethostbyname(hostname)
print(ip)
# Out:
# 169.254.97.131

# %%
import socket
s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
s.connect(("8.8.8.8", 80))
print(s.getsockname()[0])
s.close()
# Out:
# 172.17.17.28

# %%
os.listdir('/sys/class/net/')
#取得網卡資訊

# %%
from IPy import IP

# %%
import os

# %%
from scapy.all import *
#ping = sr(IP(dst='202.100.1.1')/ICMP()/b'welcome to qytang')
b = IP(dst='192.168.2.1')/ICMP()

b.show()

ping = sr1(b)     #send and receive  1個包

ping.show()
# Out:
# ###[ IP ]###
#   version   = 4
#   ihl       = None
#   tos       = 0x0
#   len       = None
#   id        = 1
#   flags     =
#   frag      = 0
#   ttl       = 64
#   proto     = icmp
#   chksum    = None
#   src       = 192.168.2.100
#   dst       = 192.168.2.1
#   \options   \
# ###[ ICMP ]###
#      type      = echo-request
#      code      = 0
#      chksum    = None
#      id        = 0x0
#      seq       = 0x0
#
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 1 answers, remaining 0 packets
# ###[ IP ]###
#   version   = 4
#   ihl       = 5
#   tos       = 0x0
#   len       = 28
#   id        = 38808
#   flags     =
#   frag      = 0
#   ttl       = 255
#   proto     = icmp
#   chksum    = 0x9e92
#   src       = 192.168.2.1
#   dst       = 192.168.2.100
#   \options   \
# ###[ ICMP ]###
#      type      = echo-reply
#      code      = 0
#      chksum    = 0xffff
#      id        = 0x0
#      seq       = 0x0

# %%
from scapy.all import *
#ping = sr(IP(dst='202.100.1.1')/ICMP()/b'welcome to qytang')
b = IP(dst='192.168.2.3')/ICMP()

b.show()

ping = sr1(b)     #send and receive  1個包

ping.show()
# Out:
# ###[ IP ]###
#   version   = 4
#   ihl       = None
#   tos       = 0x0
#   len       = None
#   id        = 1
#   flags     =
#   frag      = 0
#   ttl       = 64
#   proto     = icmp
#   chksum    = None
#   src       = 192.168.2.100
#   dst       = 192.168.2.3
#   \options   \
# ###[ ICMP ]###
#      type      = echo-request
#      code      = 0
#      chksum    = None
#      id        = 0x0
#      seq       = 0x0
#
# Begin emission:
# Finished sending 1 packets.

# %%
pip install netifaces
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import netifaces

# %%
netifaces.interfaces()
# Out:
# ['{A209A467-A5A1-4D24-A1E8-DE30C682CE31}',
#  '{1325C98A-555F-4C82-80B4-A7E2DF082E9C}',
#  '{6C84FBA6-31C1-43DE-B2D7-47B76FEFD2F0}',
#  '{4D711BB7-EF83-4E51-8A77-B3D94DF93E16}',
#  '{6CF092D8-B044-4C93-9A34-37515BEC06B5}',
#  '{41248D70-973D-4602-8AF8-00B6A78C032A}',
#  '{074A45B8-31D4-4C64-98A0-43FDCF682FFD}',
#  '{B10921B9-9F68-4E72-B49A-7B25DAC42A46}',
#  '{E3E4E956-2C4C-4EB1-9A9D-BAF81F0887DF}',
#  '{963DB9D7-6101-11E9-B118-806E6F6E6963}']

# %%
import netifaces as ni
import winreg as wr
from pprint import pprint

def get_connection_name_from_guid(iface_guids):
    iface_names = ['(unknown)' for i in range(len(iface_guids))]
    reg = wr.ConnectRegistry(None, wr.HKEY_LOCAL_MACHINE)
    reg_key = wr.OpenKey(reg, r'SYSTEM\CurrentControlSet\Control\Network\{4d36e972-e325-11ce-bfc1-08002be10318}')
    for i in range(len(iface_guids)):
        try:
            reg_subkey = wr.OpenKey(reg_key, iface_guids[i] + r'\Connection')
            iface_names[i] = wr.QueryValueEx(reg_subkey, 'Name')[0]
        except FileNotFoundError:
            pass
    return iface_names

x = ni.interfaces()
pprint(get_connection_name_from_guid(x))
# Out:
# ['區域連線* 11',
#  'VirtualBox Host-Only Network',
#  'Npcap Loopback Adapter',
#  '區域連線* 1',
#  '區域連線* 2',
#  'VMware Network Adapter VMnet1',
#  'VMware Network Adapter VMnet8',
#  'Wi-Fi',
#  '藍牙網路連線',
#  '(unknown)']

# %%
ni.interfaces(Npcap Loopback Adapter)
# Out:
#   File "<ipython-input-10-f7445783d5d2>", line 1
#     ni.interfaces(Npcap Loopback Adapter)
#                                ^
# SyntaxError: invalid syntax

# %%
from scapy.all import *
d=sniff (timeout=10)

# %%
d?

# %%
d.show()
# Out:
# 0000 Ether / IP / TCP 192.168.2.100:49779 > 202.169.175.76:https PA / Raw
# 0001 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Padding
# 0002 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0003 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0004 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0005 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0006 Ether / IP / TCP 192.168.2.100:49779 > 202.169.175.76:https A
# 0007 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0008 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0009 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0010 Ether / IP / TCP 192.168.2.100:49779 > 202.169.175.76:https A
# 0011 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# 0012 Ether / IP / TCP 202.169.175.76:https > 192.168.2.100:49779 A / Raw
# ...

# %%
IPsrc = d[IP].src
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-692bb3d5f80b> in <module>
# ----> 1 IPsrc = d[IP].src
#
# ~\Anaconda3\lib\site-packages\scapy\plist.py in __getattr__(self, attr)
#     107
#     108     def __getattr__(self, attr):
# --> 109         return getattr(self.res, attr)
#     110
#     111     def __getitem__(self, item):
#
# AttributeError: 'list' object has no attribute 'src'

# %%
import
